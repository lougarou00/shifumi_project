# %%
# les importations
import random

# %%
# L'entrée du jeu
print(" Salut gamer, viens t'amuser avec Mr Winner. Je te propose une partie de SHIFUMI avec moi")
name=input(" Please, enter your name ")
print(" Bienvenue ",name," ! . J'espère que l'on s'amusera bien ")
MrK_choice=random.randint(0,3)
# Demande du choix de la difficulté
level_difficulty=input(" Veuillez choisir un niveau de diffficulté :\nA-Easy(05 parties)\nB-Medium(03 parties)\nC-Hard(02 parties)")
nbre_parties=0
my_score=0
MrK_score=0
while True:
    if nbre_parties==2:
        if level_difficulty.strip().upper()=="C":
            print("Your score: ",my_score,"My score: ", MrK_score)
            if my_score>MrK_score:
                print("Félicitations, vous aviez gagné. Mais ce ne sera pas aussi facile la prochaine fois")
            elif my_score<MrK_score:
                print("Haaaaaaa!!! j'ai gagné. Retentez votre chance")
            else:
                print("Match nul.On se sépare bons amis")
            break
    if nbre_parties==3:
        if level_difficulty.strip().upper()=="B":
            print("Your score: ",my_score,"My score: ", MrK_score)
            if my_score>MrK_score:
                print("Félicitations, vous aviez gagné. Mais ce ne sera pas aussi facile la prochaine fois")
            elif my_score<MrK_score:
                print("Haaaaaaa!!! j'ai gagné. Retentez votre chance")
            else:
                print("Match nul.On se sépare bons amis")
            break

    if nbre_parties==5:
        if level_difficulty.strip().upper()=="A":
            print("Your score: ",my_score,"My score: ", MrK_score)
            if my_score>MrK_score:
                print("Félicitations, vous aviez gagné. Mais ce ne sera pas aussi facile la prochaine fois")
            elif my_score<MrK_score:
                print("Haaaaaaa!!! j'ai gagné. Retentez votre chance")
            else:
                print("Match nul.On se sépare bons amis")
            break

    
    shifumi_choice=int(input(" Veuillez choisir entre Pierre, Feuille et Ciseaux. Tapez \n0 pour Pierre\n1 pour Feuille \n2 pour Ciseaux"))
    if shifumi_choice==0:
        if MrK_choice==0:
            print("Vous aviez choisi Pierre, je choisis Pierre alors match nul. Réessayons une nouvelle fois")
        elif MrK_choice==1:
            print("Vous aviez choisi Pierre, je choisis Feuille . \nBingo, j'ai gagné !!!!!!")
            MrK_score+=1
        else:
            print("Vous aviez choisi Pierre, je choisis Ciseaux. \nFélicitations, vous aviez gagné!!!")
            my_score+=1
    if shifumi_choice==1:
        if MrK_choice==1:
            print("Vous aviez choisi Feuille, je choisis Feuille alors match nul. Réessayons une nouvelle fois")
        elif MrK_choice==0:
            print("Vous aviez choisi Feuille, je choisis Pierre .\nFélicitations, vous aviez gagné!!!")
            my_score+=1
        else:
            print("Vous aviez choisi Feuille, je choisis Ciseaux. \nBingo, j'ai gagné!!!")
            MrK_score+=1
    if shifumi_choice==2:
        if MrK_choice==2:
            print("Vous aviez choisi Ciseaux, je choisis Ciseaux alors match nul. Réessayons une nouvelle fois")
        elif MrK_choice==1:
            print("Vous aviez choisi Ciseaux, je choisis Feuille .\nFélicitations, vous aviez gagné!!!")
            my_score+=1
        else:
            print("Vous aviez choisi Ciseaux, je choisis Pierre . \nBingo, j'ai gagné!!!")
            MrK_score+=1
    nbre_parties+=1
# Out:
#  Salut gamer, viens t'amuser avec Mr Winner. Je te propose une partie de SHIFUMI avec moi
#  Please, enter your name Aïmane
#  Bienvenue  Aïmane  ! . J'espère que l'on s'amusera bien
#  Veuillez choisir un niveau de diffficulté :
# A-Easy(05 parties)
# B-Medium(03 parties)
# C-Hard(02 parties)                     a
#  Veuillez choisir entre Pierre, Feuille et Ciseaux. Tapez
# 0 pour Pierre
# 1 pour Feuille
# 2 pour Ciseaux1
# Vous aviez choisi Feuille, je choisis Pierre .
# Félicitations, vous aviez gagné!!!
#  Veuillez choisir entre Pierre, Feuille et Ciseaux. Tapez
# 0 pour Pierre
# 1 pour Feuille
# 2 pour Ciseaux0
# Vous aviez choisi Pierre, je choisis Pierre alors match nul. Réessayons une nouvelle fois
#  Veuillez choisir entre Pierre, Feuille et Ciseaux. Tapez
# 0 pour Pierre
# 1 pour Feuille
# 2 pour Ciseaux1
# Vous aviez choisi Feuille, je choisis Pierre .
# Félicitations, vous aviez gagné!!!
#  Veuillez choisir entre Pierre, Feuille et Ciseaux. Tapez
# 0 pour Pierre
# ...
